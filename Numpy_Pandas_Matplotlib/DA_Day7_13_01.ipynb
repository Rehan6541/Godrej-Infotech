# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=pd.DataFrame(sns.load_dataset("tips"))

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
tips.shape[0]
# Out:
# 244

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
##Distribution Plots

# %%
tips["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.distplot(tips["total_bill"])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11268\1984207902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"],bins=244)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11268\1460571009.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"],bins=244)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"],bins=244,kde=False)#kde=kernel density estimation
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11268\4068858333.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"],bins=244,kde=False)#kde=kernel density estimation
# <Axes: xlabel='total_bill'>

# %%
sns.displot(tips['total_bill'])

# %%
sns.displot(tips['total_bill'],bins=200)

# %%
sns.displot(tips['total_bill'],bins=200)

# %%
sns.displot(tips['total_bill'],bins=200,kde=True)

# %%
sns.displot(tips['tip'])

# %%
sns.displot(tips['tip'],bins=100,kde=True)

# %%
sns.displot(tips['tip'])

# %%
sns.displot(tips['tip'],bins=100,kde=True)

# %%
tips[tips['tip']>8].value_counts().sum()
# Out:
# 2

# %%
sum(tips['tip']>8)
# Out:
# 2

# %%
tips[tips["tip"] > 8]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3
# 212       48.33   9.0  Male     No  Sat  Dinner     4

# %%
#Join plot 
#allows you to basically match upto two displots for bivariate data with your choice of what kind parameter to

# %%
sns.jointplot(data=tips,x="total_bill",y="tip")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="smoker")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="sex")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="time")

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="day")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="day",palette="coolwarm")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="day",palette="rainbow")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="day",palette="Set1")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="day",palette="Set2")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind='scatter')

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind='hex')

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind='hex',hue='smoker')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 sns.jointplot(data=tips,x="total_bill",y="tip",kind='hex',hue='smoker')
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2225, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2221 if hue is not None and kind in ["hex", "reg", "resid"]:
#    2222     msg = (
#    2223         f"Use of `hue` with `kind='{kind}'` is not currently supported."
#    2224     )
# -> 2225     raise ValueError(msg)
#    2227 # Make a colormap based off the plot color
#    2228 # (Currently used only for kind="hex")
#    2229 if color is None:
#
# ValueError: Use of `hue` with `kind='hex'` is not currently supported.

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind='hist')

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind='kde')

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind='reg')

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind='reg',hue='smoker')

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind='resid')

# %%
#pairplot
#it will plot pairwise relationship an entire dataframe(for the numerical columns)

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='time')

# %%
sns.pairplot(tips,hue="day")

# %%
sns.pairplot(tips,hue="sex",kind='kde')

# %%
sns.pairplot(tips,hue="sex",kind='reg',palette='Set1')

# %%
#rugplot

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.rugplot(tips["total_bill"])
sns.kdeplot(tips['total_bill'])

# %%
sns.rugplot(tips["tip"])

sns.kdeplot(tips['tip'])
