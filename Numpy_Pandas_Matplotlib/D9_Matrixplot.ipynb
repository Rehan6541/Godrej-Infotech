# %% [raw]
# Matrix plot

# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %%
tips=sns.load_dataset("tips")

# %%
#Heatmap to understand the correlaton between features

# %%
tips.corr()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3824\3825555837.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips.corr(numeric_only=True)#to avoid warning
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.heatmap(tips.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(tips.corr(numeric_only=True),annot=True,cmap="rainbow")
# Out:
# <Axes: >

# %%
sns.heatmap(tips.corr(numeric_only=True),annot=True,cmap="Set2")
# Out:
# <Axes: >

# %%
sns.load_dataset("flights")
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights=sns.load_dataset("flights")

# %%
flights.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
flights.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
flights.shape
# Out:
# (144, 3)

# %%
sns.heatmap(flights.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.heatmap(flights.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
pv_flights=flights.pivot_table(values='passengers',index='month',columns='year')

# %%
pv_flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(pv_flights)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(pv_flights,linewidths=2,linecolor='green',cmap='Set2')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(pv_flights)

# %%
sns.clustermap(pv_flights,cmap="Set1")

# %%
##Grids

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.PairGrid(iris)

# %%
g=sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species',palette='rainbow')

# %%
g = sns.FacetGrid(tips, col="time", row="smoker")

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill")

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker",hue='sex')
g = g.map(plt.scatter, "total_bill", "tip").add_legend()

# %%
g = sns.FacetGrid(tips, col="day",  row="smoker",hue='sex')
g = g.map(plt.scatter, "total_bill", "tip").add_legend()

# %%
##Joint gridpolt

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.distplot)
# Out:
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.x, **orient_kw_x, **kwargs)
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1892: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.histplot)

# %%
#Regression plot

# %%
sns.lmplot(data=tips,x="total_bill",y="tip")

# %%
sns.lmplot(data=tips,x="total_bill",y="tip",hue="sex")

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm',
           markers=['x','.'],scatter_kws={'s':50})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='Set2',
           markers=['o','v'],scatter_kws={'s':50})

# %%
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)
