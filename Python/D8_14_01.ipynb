# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
##Categorical plots

# %%
#barplot

# %%
sns.barplot(data=tips,x="smoker",y="total_bill")  #estimator =mean by default
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(tips,x="smoker",y="total_bill",estimator=sum)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(tips,x="smoker",y="total_bill",estimator=min)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(tips,x="smoker",y="total_bill",estimator=max)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(tips,x="time",y="total_bill",estimator=sum)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="sex",y="tip",estimator='mean')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",estimator='sum')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",estimator='sum',hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",estimator='sum',hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",estimator='sum',hue='time')

# %%
sns.barplot(tips,x="day",y="total_bill",estimator='sum',hue='smoker',palette='Set3')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(tips,x="day",y="total_bill",estimator='sum',hue='smoker',palette='coolwarm')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(tips,x="day",y="total_bill",estimator='sum',hue='smoker',palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(tips,x="size",y="total_bill",estimator='sum')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(tips,x="size",y="total_bill",estimator='sum',hue="sex")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(tips,x="size",y="total_bill",estimator='sum',hue="smoker")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
##Countplot

# %%
sns.countplot(data=tips,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=tips,x="smoker")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=tips,x="smoker",hue='time')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=tips,y="smoker")
# Out:
# <Axes: xlabel='count', ylabel='smoker'>

# %%
sns.countplot(data=tips,y="day")
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.countplot(data=tips,x="day")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data=tips,x="day",hue='size')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 sns.countplot(data=tips,x="day",hue='size')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
sns.countplot(data=tips,x="day",hue="size",palette="Set2")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 sns.countplot(data=tips,x="day",hue="size",palette="Set2")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
sns.countplot(data=tips,y="day")
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.countplot(data=tips,y="day",palette="Set1",hue="size")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 sns.countplot(data=tips,y="day",palette="Set1",hue="size")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
sns.countplot(data=tips,y="day",hue="size",palette="Set1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 sns.countplot(data=tips,y="day",hue="size",palette="Set1")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
#Box plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(data=tips,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(tips["total_bill"])
# Out:
# <Axes: >

# %%
sum(tips["day"]=="Thur")
# Out:
# 62

# %%
sns.boxplot(data=tips,x="day",y="total_bill",hue="time")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,x="day",y="total_bill",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(x=tips['total_bill'],palette="rainbow")
# Out:
# <Axes: xlabel='total_bill'>

# %%
#Violoinplot

# %%
sns.violinplot(data=tips,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips,x="day",y="total_bill",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips,x="day",y="total_bill",hue="smoker",split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#stripplot

# %%
sns.stripplot(data=tips,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x="day",y="total_bill",jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x="day",y="total_bill",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x="day",y="total_bill",hue='smoker')

# %%
sns.stripplot(data=tips,x="day",y="total_bill",hue='smoker',dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x="day",y="total_bill",hue='smoker',dodge=True,jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,hue="time")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,hue="smoker",dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
sns.swarmplot(x="tip", y="day", data=tips,color='black',size=3)
# Out:
# <Axes: xlabel='tip', ylabel='day'>
